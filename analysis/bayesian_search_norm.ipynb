# %%
import pandas as pd

df = pd.read_csv('../results/latent_vectors_20241217_173316/latent_vectors.csv')[['norm']]
# Out:
#            norm
# 0     33.432358
# 1     26.882786
# 2     26.018826
# 3     32.667935
# 4     30.179904
# ...         ...
# 9995  31.064064
# 9996  32.946518
# 9997  21.174103
# 9998  31.564993
# 9999  30.831507
#
# [10000 rows x 1 columns]

# %%
# draw 10000 random vectors from the latent space

import numpy as np
# Out:
# (array([  1.,   2.,   3.,   1.,   4.,   4.,   7.,  12.,  30.,  43.,  56.,
#          92., 109., 145., 207., 262., 330., 357., 457., 457., 510., 600.,
#         566., 614., 640., 598., 583., 501., 489., 413., 398., 314., 255.,
#         232., 174., 158., 111.,  69.,  55.,  60.,  25.,  17.,  13.,   8.,
#           8.,   4.,   3.,   2.,   0.,   1.]),
#  array([2.95986464, 3.06901092, 3.1781572 , 3.28730347, 3.39644975,
#         3.50559602, 3.6147423 , 3.72388857, 3.83303485, 3.94218113,
#         4.0513274 , 4.16047368, 4.26961995, 4.37876623, 4.48791251,
#         4.59705878, 4.70620506, 4.81535133, 4.92449761, 5.03364389,
#         5.14279016, 5.25193644, 5.36108271, 5.47022899, 5.57937526,
#         5.68852154, 5.79766782, 5.90681409, 6.01596037, 6.12510664,
#         6.23425292, 6.3433992 , 6.45254547, 6.56169175, 6.67083802,
#         6.7799843 , 6.88913058, 6.99827685, 7.10742313, 7.2165694 ,
#         7.32571568, 7.43486195, 7.54400823, 7.65315451, 7.76230078,
# ...

# %%
plt.hist(df['norm'], bins=50, color='hotpink')
# Out:
# (array([  1.,   3.,   1.,   4.,   6.,  11.,  14.,  28.,  26.,  30.,  51.,
#          49.,  86., 151., 159., 213., 273., 309., 379., 406., 504., 516.,
#         589., 560., 594., 662., 602., 586., 554., 481., 432., 405., 308.,
#         262., 189., 166., 118.,  77.,  66.,  38.,  28.,  20.,  15.,  14.,
#           5.,   4.,   1.,   1.,   2.,   1.]),
#  array([17.00393283, 17.49911541, 17.99429799, 18.48948057, 18.98466315,
#         19.47984573, 19.97502831, 20.47021088, 20.96539346, 21.46057604,
#         21.95575862, 22.4509412 , 22.94612378, 23.44130636, 23.93648894,
#         24.43167152, 24.9268541 , 25.42203668, 25.91721926, 26.41240183,
#         26.90758441, 27.40276699, 27.89794957, 28.39313215, 28.88831473,
#         29.38349731, 29.87867989, 30.37386247, 30.86904505, 31.36422763,
#         31.85941021, 32.35459279, 32.84977536, 33.34495794, 33.84014052,
#         34.3353231 , 34.83050568, 35.32568826, 35.82087084, 36.31605342,
# ...
